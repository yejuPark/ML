# %% [markdown]
# # 선형 회귀

# %% [markdown]
# ## 농어의 길이로 무게 예측하기

# %% [markdown]
# ![](data:image/png;base64,...)

# %%
import pandas as pd

fish_df = pd.read_csv('./data/fish.csv')
fish_df.head()
# Out:
#      길이    무게
# 0   8.4   5.9
# 1  13.7  32.0
# 2  15.0  40.0
# 3  16.2  51.5
# 4  17.4  70.0

# %%
fish_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   길이      56 non-null     float64
#  1   무게      56 non-null     float64
# dtypes: float64(2)
# memory usage: 1.0 KB

# %%
import matplotlib.pyplot as plt

# 훈련 세트의 산점도를 그립니다
plt.scatter(fish_df['길이'], fish_df['무게'])
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import sweetviz as sv
# 경고메세지 끄기
import warnings
warnings.filterwarnings(action='ignore')

df_train = pd.read_csv('./data/fish.csv')

sv.config_parser.read_string("[General]\nuse_cjk_font=1")
my_report = sv.analyze(df_train)
# my_report.show_notebook(layout='widescreen',scale=0.8) #notebook, colab에서 표시하기
my_report.show_html(r'./image/sweet_report.html')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# 0:122: execution error: 일부 대상체 파일을 발견할 수 없습니다. (-43)
# Report ./image/sweet_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
#boxplot

fish_df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ```
# 1.결측치 : (missing) X
# 2.중복값 : (duplicates) X
# 3.이상치 : (boxplot으로 확인) X
# ```
