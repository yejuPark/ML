# %%
import pandas as pd

#데이터 로드
train_df = pd.read_csv('./data/train.csv')
test_df = pd.read_csv('./data/test.csv')

# %% [markdown]
# ## EDA

# %%
import pandas as pd
import sweetviz as sv

# 경고메세지 끄기
import warnings
warnings.filterwarnings(action='ignore')
sv.config_parser.read_string("[General]\nuse_cjk_font=1")

df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

compare_report = sv.compare([df_train,'Train'],[df_test,'Test'],target_feat='가격')
compare_report.show_html(r'./image/EDA_Report.html')
# Out:
# Done! Use 'show' commands to display/save.   |██████████| [100%]   00:00 -> (00:00 left)
# 0:121: execution error: 일부 대상체 파일을 발견할 수 없습니다. (-43)
# Report ./image/EDA_Report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가격      71 non-null     int64
#  1   년식      71 non-null     int64
#  2   종류      71 non-null     object
#  3   연비      71 non-null     float64
#  4   마력      71 non-null     int64
#  5   토크      71 non-null     float64
#  6   연료      71 non-null     object
#  7   하이브리드   71 non-null     int64
#  8   배기량     71 non-null     int64
#  9   중량      71 non-null     int64
#  10  변속기     71 non-null     object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 6.2+ KB

# %%
df_train.head()
# Out:
#      가격    년식   종류    연비   마력    토크   연료  하이브리드   배기량    중량 변속기
# 0  1885  2015  준중형  11.8  172  21.0  가솔린      0  1999  1300  자동
# 1  2190  2015  준중형  12.3  204  27.0  가솔린      0  1591  1300  자동
# 2  1135  2015   소형  15.0  100  13.6  가솔린      0  1368  1035  수동
# 3  1645  2014   소형  14.0  140  17.0  가솔린      0  1591  1090  자동
# 4  1960  2015   대형   9.6  175  46.0   디젤      0  2497  1990  자동

# %%
df_train.describe()
# Out:
#                  가격           년식         연비          마력         토크      하이브리드  \
# count     71.000000    71.000000  71.000000   71.000000  71.000000  71.000000
# mean    2488.492958  2014.436620  12.361972  175.647887  29.443662   0.042254
# std     1456.797632     1.167811   3.154333   61.207165  12.143943   0.202599
# min     1104.000000  2011.000000   6.300000  100.000000  13.600000   0.000000
# 25%     1620.000000  2015.000000   9.950000  136.000000  18.150000   0.000000
# 50%     2110.000000  2015.000000  12.400000  166.000000  27.000000   0.000000
# 75%     3044.500000  2015.000000  14.200000  200.000000  41.000000   0.000000
# max    11150.000000  2015.000000  19.000000  416.000000  52.000000   1.000000
#
#                배기량           중량
# count    71.000000    71.000000
# mean   2152.450704  1580.563380
# std     687.918699   367.027859
# min    1368.000000  1035.000000
# 25%    1591.000000  1261.000000
# 50%    1999.000000  1615.000000
# 75%    2428.000000  1903.000000
# ...

# %%
df_train.isnull().sum()
# Out:
# 가격       0
# 년식       0
# 종류       0
# 연비       0
# 마력       0
# 토크       0
# 연료       0
# 하이브리드    0
# 배기량      0
# 중량       0
# 변속기      0
# dtype: int64

# %%
import sweetviz as sv
import pandas as pd

# %%
df_train.boxplot()   ## 범주형은 boxplot으로 분석하는 의미 없음
# Out:
# <Axes: >

# %%
plt.boxplot(df_train['배기량'])
plt.show()

# %%
plt.boxplot(df_train['마력'])
plt.show()

# %%
plt.boxplot(df_train['가격'])
plt.show()

# %%
df_train['가격'].max()
# Out:
# 11150

# %%
# df_train[df_train['가격'] == 11150]
df_train[df_train['가격']>6000]
# Out:
#        가격    년식  종류   연비   마력    토크   연료  하이브리드   배기량    중량 변속기
# 64  11150  2015  대형  8.1  416  52.0  가솔린      0  5038  2065  자동

# %%
df_train['배기량'].max()
# Out:
# 5038

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ```
# 1. 결측치 : 둘다 없음
# 2. 중복값 : train(1)
# 3. 이상치 : 가격 -> max 하나 날리면 [마력, 배기량] max도 날라감
# 4. 인코딩 : 종류, 연료, 변속기(문자형-레이블) / 년식, 하이브리드(범주형-원핫인코딩)
# 5. feature와 lable의 관계성 유무 : (heatmap분석) 관계성 있음 - ML 학습 가능
# 6. 스케일링 : 아직모름
# ```

# %%
# 중복값 제거

train_df[train_df.duplicated()]
# Out:
#       가격    년식  종류    연비   마력    토크  연료  하이브리드   배기량    중량 변속기
# 16  1960  2015  대형  11.4  175  46.0  디젤      0  2497  1990  수동

# %%
print(len(train_df))
# Out:
# 71

# %%
train_df = train_df.drop_duplicates()

# %%
print(len(train_df))
# Out:
# 70

# %%
train_df[train_df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [가격, 년식, 종류, 연비, 마력, 토크, 연료, 하이브리드, 배기량, 중량, 변속기]
# Index: []

# %%
# 1차 가공 후 데이터 저장

train_df.to_csv('./data/train_pre.csv', index=False)  #index 빼고 저장

# %%
pd.read_csv('./data/train_pre.csv')
# Out:
#       가격    년식   종류    연비   마력    토크   연료  하이브리드   배기량    중량 변속기
# 0   1885  2015  준중형  11.8  172  21.0  가솔린      0  1999  1300  자동
# 1   2190  2015  준중형  12.3  204  27.0  가솔린      0  1591  1300  자동
# 2   1135  2015   소형  15.0  100  13.6  가솔린      0  1368  1035  수동
# 3   1645  2014   소형  14.0  140  17.0  가솔린      0  1591  1090  자동
# 4   1960  2015   대형   9.6  175  46.0   디젤      0  2497  1990  자동
# ..   ...   ...  ...   ...  ...   ...  ...    ...   ...   ...  ..
# 65  3802  2015   중형   8.5  290  34.8  가솔린      0  3342  1901  자동
# 66  1270  2012   소형  13.3  108  13.9  가솔린      0  1396  1040  자동
# 67  2430  2015  준중형  12.8  186  41.0   디젤      0  1995  1665  자동
# 68  2870  2015   중형  17.7  156  19.3  가솔린      1  1999  1585  자동
# 69  3254  2015   대형  13.8  202  45.0   디젤      0  2199  1691  자동
#
# [70 rows x 11 columns]
