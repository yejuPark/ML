# %% [markdown]
# ## 자동차 리콜 3개년 분석

# %% [markdown]
# ## 데이터 출처
# -  https://www.data.go.kr/data/3048950/fileData.do
#
# [받은 파일]
# - 2020년:자동차리콜현황(2020) v3.0.csv
# - 2021년:자동차리콜현황(2021).csv
# - 2022년:한국교통안전공단_자동차결함 리콜현황_20221231.csv

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#데이터 로드
df_22 = pd.read_csv('./data/한국교통안전공단_자동차결함 리콜현황_20221231.csv',encoding='euc_kr')
df_21 = pd.read_csv('./data/자동차리콜현황(2021).csv', encoding='euc_kr')
df_20 = pd.read_csv('./data/자동차리콜현황(2020) v3.0.csv', encoding='euc_kr')

# %%
df_22[df_22['제작자']=='한신특장']
# Out:
#        제작자              차명    생산기간(부터)    생산기간(까지)       리콜개시일      리콜사유
# 1281  한신특장  한신특장 울트라 고소작업차  2013-04-24  2013-09-30  2022-12-01  인증 중량 초과

# %%
# 데이터 병합
df = pd.concat([df_22, df_21, df_20])

# %%
# 데이터 중복 여부 및 개수 확인

df_22[df_22.duplicated(keep=False)]
# Out:
#                 제작자              차명    생산기간(부터)    생산기간(까지)       리콜개시일  \
# 303       대전기계공업(주)            W800  2019-02-21  2022-02-10  2022-03-28
# 304       대전기계공업(주)            W800  2019-02-21  2022-02-10  2022-03-28
# 392   메르세데스벤츠코리아(주)           A 220  2021-09-16  2021-09-16  2022-04-08
# 393   메르세데스벤츠코리아(주)           A 220  2021-09-16  2021-09-16  2022-04-08
# 527   (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-05-02
# 528   (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-05-02
# 1144   스카니아코리아그룹(주)          스카니아카고  2021-02-15  2021-02-16  2022-10-11
# 1145   스카니아코리아그룹(주)          스카니아카고  2021-02-15  2021-02-16  2022-10-11
# 1216  (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-11-01
# 1217  (주)재규어랜드로버코리아  레인지로버 이보크 2.0D  2015-05-14  2017-07-27  2022-11-01
#
#                                                    리콜사유
# 303   경음기에 전기 배선을 연결하는 단자의 내구성 부족으로 주행 중 특정한 엔진 회전 영...
# 304   경음기에 전기 배선을 연결하는 단자의 내구성 부족으로 주행 중 특정한 엔진 회전 영...
# 392   비상 통신 시스템(eCall)을 위한 통신 모듈 소프트웨어가 사양에 맞지 않아 차량...
# 393   비상 통신 시스템(eCall)을 위한 통신 모듈 소프트웨어가 사양에 맞지 않아 차량...
# 527   엔진오일오염도 증가에 따른 엔진오일펌프, 타이밍체인의 마모 및 파손 엔진오일 서비스...
# 528   엔진오일오염도 증가에 따른 엔진오일펌프, 타이밍체인의 마모 및 파손 엔진오일 서비스...
# 1144         타이로드 끝 부분에 슬롯이 없는 타이로드가 장착되어 있을 가능성이 있습니다.
# 1145         타이로드 끝 부분에 슬롯이 없는 타이로드가 장착되어 있을 가능성이 있습니다.
# 1216  엔진오일오염도 증가에 따른 엔진오일펌프, 타이밍체인의 마모 및 파손 엔진오일 서비스...
# 1217  엔진오일오염도 증가에 따른 엔진오일펌프, 타이밍체인의 마모 및 파손 엔진오일 서비스...

# %%
print("Before:", len(df_22))
df_22 = df_22.drop_duplicates()
print("After:", len(df_22))
# Out:
# Before: 1414
# After: 1414

# %%
df_22[df_22['제작자']=='한신특장']
# Out:
#        제작자              차명    생산기간(부터)    생산기간(까지)       리콜개시일      리콜사유
# 1281  한신특장  한신특장 울트라 고소작업차  2013-04-24  2013-09-30  2022-12-01  인증 중량 초과

# %%
print("Before:", len(df_21))
df_21 = df_21.drop_duplicates()
print("After:", len(df_21))
# Out:
# Before: 1962
# After: 1959

# %%
df_20[df_20.duplicated(keep=False)]
# Out:
#             제작자        차명    생산기간(부터)    생산기간(까지)       리콜개시일  \
# 34  비엠더블유코리아(주)  BMW 316i  2001-01-09  2001-01-09  2020-02-07
# 82  비엠더블유코리아(주)  BMW 316i  2001-01-09  2001-01-09  2020-02-07
#
#                                                  리콜사유
# 34  차량이 고온 다습한 지역에 장기간 노출 되었을 때 에어백 인플레이터 내부 압축가스 ...
# 82  차량이 고온 다습한 지역에 장기간 노출 되었을 때 에어백 인플레이터 내부 압축가스 ...

# %%
print("Before:", len(df_20))
df_20 = df_20.drop_duplicates()
print("After:", len(df_20))
# Out:
# Before: 1275
# After: 1274

# %%
df_22[df_22['제작자']=='한신특장']
# Out:
#        제작자              차명    생산기간(부터)    생산기간(까지)       리콜개시일      리콜사유
# 1281  한신특장  한신특장 울트라 고소작업차  2013-04-24  2013-09-30  2022-12-01  인증 중량 초과

# %% [markdown]
# ## 1. 제조사별 리콜 현황
# * 3년동안 리콜 건수가 가장 많은 제조사는?
# * 시각화를 통해 근거 자료 만들기

# %%
df_22.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1414 entries, 0 to 1418
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       1414 non-null   object
#  1   차명        1414 non-null   object
#  2   생산기간(부터)  1414 non-null   object
#  3   생산기간(까지)  1414 non-null   object
#  4   리콜개시일     1414 non-null   object
#  5   리콜사유      1414 non-null   object
# dtypes: object(6)
# memory usage: 77.3+ KB

# %%
df_21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1959 entries, 0 to 1961
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       1959 non-null   object
#  1   차명        1959 non-null   object
#  2   생산기간(부터)  1959 non-null   object
#  3   생산기간(까지)  1959 non-null   object
#  4   리콜개시일     1959 non-null   object
#  5   리콜사유      1959 non-null   object
# dtypes: object(6)
# memory usage: 107.1+ KB

# %%
df_20.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1274 entries, 0 to 1274
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       1274 non-null   object
#  1   차명        1274 non-null   object
#  2   생산기간(부터)  1274 non-null   object
#  3   생산기간(까지)  1274 non-null   object
#  4   리콜개시일     1274 non-null   object
#  5   리콜사유      1274 non-null   object
# dtypes: object(6)
# memory usage: 69.7+ KB

# %%
df_2221 = pd.concat([df_22, df_21])

# %%
df_2221[df_2221['제작자']=='한신특장']
# Out:
#        제작자              차명    생산기간(부터)    생산기간(까지)       리콜개시일      리콜사유
# 1281  한신특장  한신특장 울트라 고소작업차  2013-04-24  2013-09-30  2022-12-01  인증 중량 초과

# %%
df = pd.concat([df_2221, df_20])

# %%
df[df['제작자']=='한신특장']
# Out:
#        제작자              차명    생산기간(부터)    생산기간(까지)       리콜개시일      리콜사유
# 1281  한신특장  한신특장 울트라 고소작업차  2013-04-24  2013-09-30  2022-12-01  인증 중량 초과

# %%
df.head(10)
# Out:
#            제작자                            차명    생산기간(부터)    생산기간(까지)  \
# 0  비엠더블유코리아(주)            X4 xDrive20d xLine  2018-06-15  2019-03-22
# 1  비엠더블유코리아(주)  X3 xDrive20d M Sport Package  2017-09-04  2019-03-23
# 2  비엠더블유코리아(주)                   520d xDrive  2016-05-23  2018-06-14
# 3  비엠더블유코리아(주)                   520d xDrive  2015-11-10  2015-11-10
# 4  비엠더블유코리아(주)                   520d xDrive  2014-06-13  2016-10-27
# 5  비엠더블유코리아(주)                          520d  2016-09-13  2018-06-14
# 6  비엠더블유코리아(주)                          520d  2016-02-01  2016-02-01
# 7  비엠더블유코리아(주)                          520d  2014-06-10  2016-10-25
# 8  비엠더블유코리아(주)        420d xDrive Gran Coupe  2017-04-06  2020-08-28
# 9  비엠더블유코리아(주)        420d xDrive Gran Coupe  2015-03-25  2017-02-24
#
#         리콜개시일                        리콜사유
# 0  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 1  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 2  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 3  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 4  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 5  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 6  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 7  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 8  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성
# 9  2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성

# %%
df['리콜개시일'] = pd.to_datetime(df['리콜개시일'])
df['리콜_년'] = df['리콜개시일'].dt.year
df['리콜_월'] = df['리콜개시일'].dt.month
df['리콜_일'] = df['리콜개시일'].dt.day

# %%
df.head()
# Out:
#            제작자                            차명    생산기간(부터)    생산기간(까지)  \
# 0  비엠더블유코리아(주)            X4 xDrive20d xLine  2018-06-15  2019-03-22
# 1  비엠더블유코리아(주)  X3 xDrive20d M Sport Package  2017-09-04  2019-03-23
# 2  비엠더블유코리아(주)                   520d xDrive  2016-05-23  2018-06-14
# 3  비엠더블유코리아(주)                   520d xDrive  2015-11-10  2015-11-10
# 4  비엠더블유코리아(주)                   520d xDrive  2014-06-13  2016-10-27
#
#        리콜개시일                        리콜사유  리콜_년  리콜_월  리콜_일
# 0 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16
# 1 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16
# 2 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16
# 3 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16
# 4 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

tmp = df.groupby('제작자').size().sort_values(ascending=False).to_frame('count').head(5)

x = tmp.index
y = tmp['count']

plt.figure(figsize=(4,3))   
plt.bar(x=x,height=y)      

plt.xticks(rotation=270)  
plt.title('제조사별 리콜건수 현황')  
plt.show()

# %% [markdown]
# ```
# 문제: 3년동안 리콜건수가 가장 많은 제조사는?
# 답: 비엠더블유코리아(주)
#
# ```

# %% [markdown]
# ## 2.(그나마) 튼튼하게 만드는 기업 vs  Worst 기업 top10
#
# * 출고 년도부터 리콜 개시일 사이의 기간을 사용기간이라고 할때,
# * 이 사용기간이 길면 길수록 그나마 튼튼하게 만들었다고 볼 수 있다.
# * 물론, 여기 리콜현황에 등록되지 않은 제조사가 베스트이겠지만....
# * 사용기간의 평균이 가장 높고 낮은 10개 기업 리스트를 알아보자

# %%
df.head(3)
# Out:
#            제작자                            차명    생산기간(부터)    생산기간(까지)  \
# 0  비엠더블유코리아(주)            X4 xDrive20d xLine  2018-06-15  2019-03-22
# 1  비엠더블유코리아(주)  X3 xDrive20d M Sport Package  2017-09-04  2019-03-23
# 2  비엠더블유코리아(주)                   520d xDrive  2016-05-23  2018-06-14
#
#        리콜개시일                        리콜사유  리콜_년  리콜_월  리콜_일
# 0 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16
# 1 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16
# 2 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16

# %%
df['생산기간(까지)'] = pd.to_datetime(df['생산기간(까지)'])
df['출고_년'] = df['생산기간(까지)'].dt.year
df['출고_월'] = df['생산기간(까지)'].dt.month
df['출고_일'] = df['생산기간(까지)'].dt.day

# %%
df.head(3)
# Out:
#            제작자                            차명    생산기간(부터)   생산기간(까지)  \
# 0  비엠더블유코리아(주)            X4 xDrive20d xLine  2018-06-15 2019-03-22
# 1  비엠더블유코리아(주)  X3 xDrive20d M Sport Package  2017-09-04 2019-03-23
# 2  비엠더블유코리아(주)                   520d xDrive  2016-05-23 2018-06-14
#
#        리콜개시일                        리콜사유  리콜_년  리콜_월  리콜_일  출고_년  출고_월  출고_일
# 0 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16  2019     3    22
# 1 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16  2019     3    23
# 2 2022-02-16  배기가스재순환장치 쿨러 내부 냉각수 누설 가능성  2022     2    16  2018     6    14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4647 entries, 0 to 1274
# Data columns (total 12 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       4647 non-null   object
#  1   차명        4647 non-null   object
#  2   생산기간(부터)  4647 non-null   object
#  3   생산기간(까지)  4647 non-null   datetime64[ns]
#  4   리콜개시일     4647 non-null   datetime64[ns]
#  5   리콜사유      4647 non-null   object
#  6   리콜_년      4647 non-null   int32
#  7   리콜_월      4647 non-null   int32
#  8   리콜_일      4647 non-null   int32
#  9   출고_년      4647 non-null   int32
#  10  출고_월      4647 non-null   int32
#  11  출고_일      4647 non-null   int32
# dtypes: datetime64[ns](2), int32(6), object(4)
# memory usage: 363.0+ KB

# %%
df.drop(columns = ['생산기간(까지)', '리콜개시일'], inplace=True )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4647 entries, 0 to 1274
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   제작자       4647 non-null   object
#  1   차명        4647 non-null   object
#  2   생산기간(부터)  4647 non-null   object
#  3   리콜사유      4647 non-null   object
#  4   리콜_년      4647 non-null   int32
#  5   리콜_월      4647 non-null   int32
#  6   리콜_일      4647 non-null   int32
#  7   출고_년      4647 non-null   int32
#  8   출고_월      4647 non-null   int32
#  9   출고_일      4647 non-null   int32
# dtypes: int32(6), object(4)
# memory usage: 290.4+ KB

# %%
# 사용기간 컬럼 새로 만들기(파생변수 생성해서)
# 사용기간 : '리콜_년' - '출고_년'
df['사용기간'] = df['리콜_년'] - df['출고_년']

# %%
# 제조사별 사용기간이 가장 긴 순서대로 정렬
df.sort_values(by='사용기간', ascending=False, inplace=True)

# %%
df.head(5)
# Out:
#                  제작자            차명    생산기간(부터)  \
# 1016  폭스바겐그룹코리아 주식회사        A6 2.4  1997-06-04
# 1020  폭스바겐그룹코리아 주식회사  A8 2.8 quat.  1997-08-19
# 1017  폭스바겐그룹코리아 주식회사        A4 1.8  1997-08-26
# 843      비엠더블유코리아(주)          318i  1998-11-13
# 831      비엠더블유코리아(주)         320Ci  1999-08-02
#
#                                                    리콜사유  리콜_년  리콜_월  리콜_일  \
# 1016  특정 기간 내 특정 업체에서 생산된 운전석 에어백 유닛의 기밀성 불량으로 인하여, ...  2021     8     3
# 1020  특정 기간 내 특정 업체에서 생산된 운전석 에어백 유닛의 기밀성 불량으로 인하여, ...  2021     8     3
# 1017  특정 기간 내 특정 업체에서 생산된 운전석 에어백 유닛의 기밀성 불량으로 인하여, ...  2021     8     3
# 843   리콜 과정에서 에어백 교체 차량에서 회수한 에어백 인플레이터*를 해당 에어백의 제조...  2021     6    25
# 831   리콜 과정에서 에어백 교체 차량에서 회수한 에어백 인플레이터*를 해당 에어백의 제조...  2021     6    25
#
#       출고_년  출고_월  출고_일  사용기간
# 1016  1997    11     6    24
# 1020  1997     9     9    24
# 1017  1998    10     9    23
# 843   1999     6    22    22
# 831   2000     4    27    21

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

tmp = df.groupby('제작자').size().sort_values(ascending=False).to_frame('사용기간').head(10)

# print(tmp)

x = tmp.index
y = tmp['사용기간']

plt.figure(figsize=(4, 4))   
plt.bar(x=x,height=y)    
plt.title('사용기간(연도) 긴 제조사')    

plt.xticks(rotation=270)  
plt.show()

# %%
import matplotlib.pyplot as plt
plt.rc('font', family='AppleGothic')
plt.rcParams['axes.unicode_minus'] = False

tmp = df.groupby('제작자').size().sort_values(ascending=False).to_frame('사용기간').tail(10)

x = tmp.index
y = tmp['사용기간']

plt.figure(figsize=(4, 4))   
plt.bar(x=x,height=y) 
plt.xticks(rotation=270) 
plt.title('사용기간(연도) 짧은 제조사')
# Out:
# Text(0.5, 1.0, '사용기간(연도) 짧은 제조사')

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.rc('font', family = "Malgun Gothic") #한글사용
plt.rcParams['axes.unicode_minus']=False #마이너스 부호 깨짐

# %% [markdown]
# ```
# 문제:그나마 튼튼 제조사 top 3는?
# 답: 비엠더블유코리아(주), 메르세데스벤츠코리아(주), 폭스바겐그룹코리아 주식회사
# ```

# %% [markdown]
# ## 3. 리콜이 가장 많은 제조사 1위의 리콜 원인은 ?
# * 리콜 대마왕 XXX 기업의 문제의 모델 xxx에 대해 대규모 손해배상청구 소송을 진행하려 한다.
# * 이 회사의 주요 리콜 사유를 알아내고,(워드 클라우드로 제작해서 키워드 추출)
# * 해당 사유로 리콜된 최고 문제 모델을 찾아내서
# * 소송으로 가즈아~

# %%
df.head()
# Out:
#                  제작자            차명    생산기간(부터)  \
# 1016  폭스바겐그룹코리아 주식회사        A6 2.4  1997-06-04
# 1020  폭스바겐그룹코리아 주식회사  A8 2.8 quat.  1997-08-19
# 1017  폭스바겐그룹코리아 주식회사        A4 1.8  1997-08-26
# 843      비엠더블유코리아(주)          318i  1998-11-13
# 831      비엠더블유코리아(주)         320Ci  1999-08-02
#
#                                                    리콜사유  리콜_년  리콜_월  리콜_일  \
# 1016  특정 기간 내 특정 업체에서 생산된 운전석 에어백 유닛의 기밀성 불량으로 인하여, ...  2021     8     3
# 1020  특정 기간 내 특정 업체에서 생산된 운전석 에어백 유닛의 기밀성 불량으로 인하여, ...  2021     8     3
# 1017  특정 기간 내 특정 업체에서 생산된 운전석 에어백 유닛의 기밀성 불량으로 인하여, ...  2021     8     3
# 843   리콜 과정에서 에어백 교체 차량에서 회수한 에어백 인플레이터*를 해당 에어백의 제조...  2021     6    25
# 831   리콜 과정에서 에어백 교체 차량에서 회수한 에어백 인플레이터*를 해당 에어백의 제조...  2021     6    25
#
#       출고_년  출고_월  출고_일  사용기간
# 1016  1997    11     6    24
# 1020  1997     9     9    24
# 1017  1998    10     9    23
# 843   1999     6    22    22
# 831   2000     4    27    21

# %%
# 리콜건수가 가장 많은 제조사는? 비엠더블유코리아(주)
df['제작자'].value_counts().head(1)
# Out:
# 제작자
# 비엠더블유코리아(주)    1809
# Name: count, dtype: int64

# %%
tmp = df.groupby('제작자').size().sort_values(ascending=False).to_frame('count')
print(f'리콜건수가 가장 많은 제조사는? {tmp.index[0]}')
# Out:
# 리콜건수가 가장 많은 제조사는? 비엠더블유코리아(주)

# %%
# 리콜 사유는?
df_bmw = df[df['제작자']=='비엠더블유코리아(주)']
df_bmw['리콜사유'].values
# Out:
# array(['리콜 과정에서 에어백 교체 차량에서 회수한 에어백 인플레이터*를 해당 에어백의 제조사인 Joyson Safety Systems(JSS)에서 추가 분석한 결과 에어백의 밀봉 불량 가능성이 발견되었습니다.',
#        '리콜 과정에서 에어백 교체 차량에서 회수한 에어백 인플레이터*를 해당 에어백의 제조사인 Joyson Safety Systems(JSS)에서 추가 분석한 결과 에어백의 밀봉 불량 가능성이 발견되었습니다.',
#        '차량이 고온 다습한 지역에 장기간 노출 되었을 때 에어백 인플레이터 내부 압축가스 추진체가 변형되어 에어백 전개 시 인플레이터의 과도한 폭발 압력으로 에어백이 전개될 수 있습니다.',
#        ...,
#        '운전석 차문 내부에서 차문 외부 손잡이와 차문 잠금 장치 사이에 장착되어야 하는 어댑터 브라켓이 장착되지 않았을 가능성이 있습니다 *어댑터 브라켓: 차문 외부 손잡이의 열쇠 실린더와 도어 잠금 장치 사이에 연결되어 차량의 잠금을 조작할 수 있는 연결봉(커넥팅 로드)의 덮개로서, 외부로부터의 차문 잠금 상태의 수동 조작을 방지합니다. 또한 측면 충격 등에 의해 장치들의 위치 변경이 발생 경우, 차문 외부 손잡이와 도어 잠금 장치 사이를 고정하여 구조적 위치를 유지시켜 주는 구성품',
#        'BMW 자체 품질조사결과 2021년 02월 09일에 생산 된 BMW X5 xDrive 45e 차량에서 뒷좌석 창가 쪽 양쪽 머리받침대의 제작결함이 발견 되었습니다.',
#        '배터리 셀 생산 공정 중에 손상된 음극판 조각이 배터리 셀 내부에 유입되어 고전압 배터리에 단락이 발생할 수 있습니다.'],
#       dtype=object)

# %%
# 워드클라우드를 사용해 키워드 추출

from wordcloud import WordCloud, STOPWORDS
set(STOPWORDS)
spwords = set(['되었습니다','발견','되었습니다.',"수이기는","적은 수이기는","동안", "인하여", "있는", "경우", "있습니다", "가능성이", "않을", "차량의", "가", "에", "될", "이",
               "인해", "수", "중", "시", "또는", "있음", "의", "및", "있으며", "발생할", "이로", "오류로", "해당", "있어", "내에",
                "못", '으로", "의한', "위해", '후', '할', '로', '더', '와', '나', '전', '매우', '등', '내에', '을', '함'])

caselist = result['리콜사유'].values
text = ' '.join(caselist)
len(text)


font_path = './NanumGothic.ttf'
wc1 = WordCloud(max_font_size=200, stopwords=spwords, font_path=font_path,
                background_color='white', width=800, height=800)
wc1.generate(text)

plt.figure(figsize=(6, 4))
plt.imshow(wc1)
plt.tight_layout()
plt.axis('off')
plt.show()

# %%
text = ''.join(df_bmw['리콜사유'].values)

# %%
from wordcloud import WordCloud, STOPWORDS
set(STOPWORDS)
spwords = set(['2020년', '31일부터', '28일까지', '8월', '3월', '극히', '드문', '일부', '결과', '생산된', 'BMW', '자체', '에서', '차량에서', '되었습니다','발견','되었습니다.',"수이기는","적은 수이기는","동안", "인하여", "있는", "경우", "있습니다", "가능성이", "않을", "차량의", "가", "에", "될", "이",
               "인해", "수", "중", "시", "또는", "있음", "의", "및", "있으며", "발생할", "이로", "오류로", "해당", "있어", "내에",
                "못", '으로", "의한', "위해", '후', '할', '로', '더', '와', '나', '전', '매우', '등', '내에', '을', '함'])

font_path = './NanumGothic.ttf'
wc1 = WordCloud(max_font_size=200, stopwords=spwords, font_path=font_path,
                background_color='white', width=800, height=800)

wc1.generate(text)

plt.figure(figsize=(6, 4))
plt.imshow(wc1)
plt.tight_layout()
plt.axis('off')
plt.show()

# %%
df_bmw['리콜사유'].drop_duplicates().values
# Out:
# array(['리콜 과정에서 에어백 교체 차량에서 회수한 에어백 인플레이터*를 해당 에어백의 제조사인 Joyson Safety Systems(JSS)에서 추가 분석한 결과 에어백의 밀봉 불량 가능성이 발견되었습니다.',
#        '차량이 고온 다습한 지역에 장기간 노출 되었을 때 에어백 인플레이터 내부 압축가스 추진체가 변형되어 에어백 전개 시 인플레이터의 과도한 폭발 압력으로 에어백이 전개될 수 있습니다.',
#        'BMW 3시리즈 모델 중 일부 차량에서 운전자석 TAKATA 에어백에 제작결함이 발견 되었 습니다. 사고가 발생한 차량을 해당 에어백의 제조사인 Joyson Safety System(JSS)*에서 조사한 결과, 1999년 4월 이전에 제작된 NADI 인플레이터 (가스 제너레이터) 일부에서 밀봉 불량의 가능성이 확인 되었습니다.',
#        '블로우바이히터 조립 공정 중, 블로우바이히터 PTC(Positive temperature coefficient) 발열체*와 구리관 사이가 벌어진 상태로 조립되었을 가능성이 발견되었습니다.',
#        '플라스틱 구조의 연료펌프 플라스틱 케이스 테두리가 노후화 되어 내구성의 부족으로 균열이 발생 할 가능성이 있습니다.',
#        '원동기 출력',
#        'BMW 자체 품질 조사 결과 2007년 11월 13일부터 2015년 5월 29일까지 생산된 BMW 520d 등 56개모델의 일부 차량에서 타이밍체인①과 관련한 제작결함이 발견 되었습니다. 사용시간 경과에 따라 타이밍체인의 늘어남은 발생할 수 있으나 타이밍체인 텐셔너가 장력을 유지시켜줍니다. 다만, 주행 조건(극심한 정체, 짧은 주행거리 등)에 따른 DPF(디젤미립자필터)의 재생 빈도와 수준 등의 영향으로 연료(경유)가 엔진오일과 희석될 수 있습니다.',
#        '타이밍체인①의 사용시간 경과에 따라 타이밍체인의 늘어남은 발생할 수 있으나 타이밍체인 텐셔너가 장력을 유지시켜줍니다. 다만, 주행 조건(극심한 정체, 짧은 주행거리 등)에 따른 DPF(디젤미립자필터)의 재생 빈도와 수준 등의 영향으로 연료(경유)가 엔진오일과 희석될 수 있으며 이에 따라 타이밍체인의 마모율이 더 높아져 체인이 비 정상적으로 늘어 날 수 있습니다. 1) 타이밍체인: 흡/배기 밸브의 개폐와 크랭크축과 연결된 피스톤의 동작이 각 행정에 따라 알맞게 작동하도록 하는 체인장치',
#        '연료펌프 제작 과정 중 연료호스 연결부에 일정압력 이상의 압력이 전달되어 미세한 내부적 균열이 발생할 가능성이 있습니다.',
#        'BMW 자체 품질 조사 결과 2010년 06월 25일부터 2019년 05월 16일까지 제작된 BMW 1 Series Sport, 220d Coupe, 320d, 320d ED, 320d Gran Turismo, 320d Touring, 320d xDrive, 320d xDrive Gran Turismo, 320d xDrive Touring, 420d Coupe, 420d Gran Coupe, 420d xDrive Gran Coupe, 435d xDrive Gran Coupe, 520d, 520d xDrive, 530d xDrive, 535d, 640d xDrive Gran Coupe, 730d xDrive, 730Ld, 740d xDrive, Gran Turismo 30d, Gran Turismo 30d xDrive, Gran Turismo EfficientDynamics Edition, GT 20d, GT 30d, GT 30d xDrive, X1 xDrive20d, X3 xDrive20d, X3 xDrive30d, X4 xDrive30d, X5 xDrive30d, X5 xDrive40d, X6 xDrive30d, X6 xDrive40d 차량 총 8,320대에서 고압 연료 펌프와 관련된 결함을 확인했습니다.',
#        '배기가스재순환장치 쿨러 내부 냉각수 누설 가능성',
#        '고압 연료 펌프의 설계 결함으로 내부 롤러의 마모에 의해 쇳가루가 발생하고, 발생된 쇳가루가 연료 공급라인(유량 제어 밸브 및 인젝터)을 막을 수 있습니다.',
#        'BMW 자체 품질 조사 결과 2011년 01월 29일부터 2011년 05월17일까지 제작된 BMW 1 M Coupe, 320d ED, 335i, 335i Convertible, 520d, 535i, 730d, 730Ld, 740i, 740Li, Gran Turismo 30d, Z4 sDrive35i 차량 총 2,066대에서 프로펠러샤프트 플렉서블 디스크*의 제작 결함 가능성이 발견되어 2017년 3월24일부터 리콜(2017RIV066)을 실시한 바 있습니다. 다만, 해당 리콜 대상 차량 중 2011년 02월 04일부터 2011년 05월17일까지 제작된 BMW 320d, 335i, 520d, 530d, 535i, 730d, 730Ld, 740Li, M Coupe, Z4 sDrive 차량 총 574대가 프로펠러샤프트 플렉서블 디스크 교환 없이 출고 된 것이 확인되었습니다.',
#        '오일필터 하우징 재질 문제로 극히 드문 경우 엔진오일과 냉각수가 섞일 수 있습니다.',
#        'BMW 자체 품질조사 결과 2011년 3월 31일부터 2020년 8월 28일까지 생산된 BMW 118d, 120d, 220d, 320d, 323d, 328d, 420d, 435d, 518d, 520d, 525d, 530d, 535d, 630d, 640d, 730d, 730Ld, 740d, 740Ld,750Ld, 840d, M550d, X1, X3, X4, X4 M40d, X5, X5 M50d, X6, X6 M50d, X7 모델 중 일부 차량에서 극히 드문 경우, 배기가스재순환장치(EGR) 쿨러의 제작결함이 발견 되었습니다.',
#        '배기가스재순환장치 냉각기 결함으로 냉각수가 누출될 수 있고, 그 결과 배기가스재순환장치 냉각기를 통과하는 배출가스와 만나면, 냉각수 중 수분은 증발하고 글리콜만 남게 됩니다. 글리콜은 wave fin구조의 내부, 배기가스재순환장치 냉각기의 입구 근처, 그리고 배기가스재순환장치 냉각기 끝 단에서 배기가스재순환장치 냉각기 내의 그을음과 혼합될 수 있습니다. 그 곳에서는 혼합물을 발화시키거나 글로잉 입자(열점)를 발생시킬 수 있는 고온 상태가 발생 할 수 있습니다.이러한 과정에 의하여 글로잉 입자가 흡기다기관 안으로 날아가 흡기다기관 표면에 붙게 되고 해당 영역이 용융하여 천공이 생길 가능성이 있습니다.',
#        '당사는 당사의 EGR 쿨러가 이전 리콜 대상 EGR 쿨러에 비하여 개선되고 최적화 되었음을 입증하였습니다. 당사의 철학과 경영 정책에 따라, 개별 현장 사례의 분석을 계속하였습니다. 그 결과, 지속적인 노력을 통해 상황이 개선되었음에도, 현장에서 적은 수이기는 하나 EGR 쿨러의 누수가 의심되는 사례를 관찰하게 되었습니다. 이에 고객의 이익과 편의를 충실히 보호하고, 동시에 당사에 매우 중요한 한국 시장을 보호하기 위하여, 현장의 적은 수이기는 하나 이러한 의심 사례를 대처하고 해소하기 위한 예방적인 조치를 취하기로 결정하였습니다. 중요한 점으로서, 당사는 귀 기관과 자동차안전연구원에 모든 것을 투명하게 공개하며, 위와 같은 상황을 명확히 전달 드려왔고, 귀 기관 및 자동차안전연구원과의 충분한 논의를 거친 후, 이번 리콜을 시행하기로 결정하였다는 점을 말씀드립니다.',
#        '2018 년 8 월 20 일부터 배기가스재순환장치 냉각기에 대하여 EGR 모듈 교체 방식을 통해 제작결함시정조치를 진행하고 있습니다. 다만, 배기가스재순환장치 냉각기에 대한 전세계적인 기술 조치를 점검하는 과정에서, 해외에서 판매되거나 수리 받은 이력이 있는 경우(11 대), 2017 년 6 월 이후 생산 차량에 2016 년 생산 냉각기가 장착된 경우(9 대) 및 2017 년 3 월 이후 생산 차량으로 냉각기 생산일이 확인되지 않아 2016 년 생산 냉각기가 장착되었을 가능성이 있는 경우(52 대)로 대상 차대가 일부 추가될 필요가 있음이 최근 확인되었습니다. 이에 따라 추가된 차량에 대하여 본건 리콜에 포함하여 실시하려 합니다.',
#        '제조 공정상의 오류로 부품간의 체결이 부정확하여 변속기 구성 부품인 단일기어(6단기어), 시프트포크(기어변속부품), 시프팅슬리브(시프트포크와 체결되는 부품)가 손상될 수 있는 가능성이 있습니다.',
#        'Rolls-Royce 자체 품질조사결과 2014년 05월 23일부터 2018년 11월 26일까지 생산 된 Rolls-Royce Cullinan, Ghost, Ghost Extended Wheelbase, Phantom, Wraith 차량의 환희의 여신상(Spirit of Ecstasy)에서 제작결함이 발견 되었습니다.',
#        'BMW 자체 품질조사 결과 2014년 04월 22일부터 2015년 02월 26일까지 생산 된 BMW 118d, 320d, 320d ED, 320d Touring, 320d xDrive, 320d xDrive Gran Turismo, 328d, 328d xDrive, 420d Gran Coupe, 420d xDrive Gran Coupe 차량에서 연료공급호스의 제작결함이 발견 되었습니다.',
#        '2012년 07월 26일부터 2015년 05월 13일까지 생산된 BMW 320d xDrive, 320d xDrive Gran Turismo, 320d xDrive Touring, 328d xDrive, 420d xDrive Coupe, 420d xDrive Gran Coupe 차량에서 프로펠러샤프트(Propeller shaft)①의 등속조인트 디스크(Constant Velocity Joint Disc)②와 관련한 제작결함이 발견 되었습니다. 엔진의 높은 진동과 등속조인트 디스크의 낮은 감쇠력③으로 인해 트렌스퍼케이스(Transfer case)④와 프로펠러샤프트가 연결되는 스플라인(Spline)⑤이 마모될 수 있습니다. ①프로펠러샤프트(Propeller shaft): 엔진의 구동력을 전, 후방으로 전달해 주는 동력 전달장치 ②등속조인트 디스크(Constant Velocity Joint Disc): 회전속도의 변화가 없이 구동력을 전달해 주기 위한 장치 ③감쇠력: 진동을 흡수하는 힘 ④트렌스퍼케이스(Transfer case): 4륜구동 차량에서 동력을 전, 후방으로 배분하는 장치 ⑤스플라인(Spline): 동력이 실질적으로 전달되는 기어',
#        'BMW 자체 품질 조사 결과 2013년 02월 04일부터 2017년 02월 21일까지 생산된 BMW M6 차량 일부에서 보조 제동등(Third Break Lamp)* 고정너트와 관련한 제작결함이 발견 되었습니다. 보조 제동등의 고정너트의 불 충분한 고정력이 발견 되었습니다. *보조 제동등(Third Break Lamp): 차량의 후면유리 상단부에 장착되며 주 제동등을 보조하는 목적으로 제동 시 점등되는 제동등',
#        '당사의 문서번호 『BGK-2022-A61-027』로 제출한 엔진 컨트롤유닛(DDE) 시정조치계획보고 『2022RIV063』와 관련하여 BMW 독일 본사로부터 추가 대상 차량을 전달 받아 추가 보고 드립니다. 엔진 컨트롤 유닛 (DDE)의 진단 관련 소프트웨어의 오류가 있는 것을 확인하였습니다.',
#        '축간 거리의 제원',
#        '2014년 01월 08일부터 2019년 05월 16일까지 생산된 BMW X6 모델 중 일부 차량에서 2열 좌석의 어린이 보호용 좌석부착장치(ISOFIX)내 브라켓의 제작결함이 발견 되었습니다. 어린이 보호용 좌석부착장치(ISOFIX)의 강도 부족으로 인해 고정된 카시트에 탑승하는 어린이의 체중, 사용빈도, 도로조건 등 복합적 요인에 따라 드문 경우에, 과도한 진동으로 인하여 ISOFIX 브라켓①의 U-bolt②가 Carrier plate③로부터 떨어질 수 있습니다. ①브라켓: ISOFIX를 구성하는 U-bolt와 Carrier plate의 조립체 ②U-bolt: 카시트의 걸쇠와 연결되는 부분 ③Carrier plate: U-bolt가 고정되어 있는 차체 부품',
#        '상부 타이밍 체인 생산 과정에서 상부 타이밍 체인에 코팅 작업이 누락되어 내구성이 부족할 수 있음을 확인했습니다.',
#        '수동변속기의 6단 기어가 생산 공정 오류로 내구성이 부족한 부품이 장착되어 시간이 지남에 따라 해당 부품이 마모되어 파손될 수 있는 가능성이 있습니다.',
#        '스타터 모터의 전원을 공급하는 솔레노이드에 차량 사고 등의 사유로 외부 충격이 가해지거나, 내부 전원 단자를 연결 및 차단시키는 리턴 스프링의 파손이 발생할 수 있습니다.',
#        '엔진 컨트롤 유닛 (DDE)의 진단 관련 소프트웨어의 오류가 있는 것을 확인하였습니다.',
#        'MINI 자체 품질 조사 결과 2013년 12월 03일부터 2020년 06월 30일까지 제작된 MINI Cooper D, Cooper D Clubman, Cooper D Five Door, Cooper SD, Cooper SD Clubman, Cooper SD Five Door 차량 총 12,147대의 차량 생산 과정에서 연료 라인*을 고정시켜주는 클립의 조립 불량을 확인했습니다.',
#        '양산 전 제작된 차량을 폐기하는 과정에서 헤드 에어백이 비 정상적으로 전개된 것이 확인 되었고 에어백 제조사(Joyson Safety Systems)와 관련 결함을 조사한 결과 헤드 에어백을 생산하는 과정에서 에어백을 팽창 시키는 압축가스 추진제① 내에 높은 습기가 내포된 것이 확인 되었습니다.',
#        '후방 서스펜션 링크의 생산 공정 오류로 내구성이 부족한 부품이 장착되어 시간이 지남에 따라 해당 부품이 파손 및 손상될 수 있는 가능성이 있습니다.',
#        '연료 필터와 결합된 히터 내부의 밀봉이 제대로 되지 않았을 경우, 연결 부위에서 소량의 연료가 누유되서 전원 분배기** 내부로 유입되어 전원 공급이 제대로 되지 않을 수 있습니다. *연료 필터 히터 : 겨울철 디젤 연료의 온도 감소를 방지하거나 엔진이 작동하는 동안 디젤 연료의 특정 온도를 유지시키는 장치 **전원 분배기(Integrated Voltage Module) : 구동장치 전압 공급에 사용되는 전자모듈',
#        'BMW 자체 품질 조사 결과 2018년 12월 21일부터 2021년 10월 06일까지 제작된 BMW X7 M50d, X7 M50i, X7 xDrive30d, X7 xDrive40d, X7 xDrive40i 차량의 3열 시트 등받이에서 제작결함이 발견되었습니다. 3열 시트 등받이의 전동식 접이 기능에 필요한 압축 스프링이 정확하게 설치되지 않았거나 누락 되어있을 가능성을 발견했습니다',
#        '배터리 셀 생산 공정 중 셀 내부 전극이 정상적으로 재단되지 않아 와인딩* 과정에서 분리막에 손상이 발생할 수 있습니다.',
#        '현장에서 매우 적은 수이기는 하나 B47D-1 엔진의 EGR 쿨러에서 누수가 의심되는 사례가 발견되었습니다',
#        '공급 업체의 부품 생산 공정에서 발생한 문제로 발전기의 배선간 간격이 협소하여 차량 진동등에 의해 발전기 배선이 소손 및 단선 될 가능성이 있습니다.',
#        "차량 전면부 그릴 등화가 '자동차 및 자동차부품의 성능과 기준에 관한 규칙' 제40조(차폭등)의 고장 시 작동기준을 충족하지 못하는 것으로 확인되었습니다.",
#        '공정상의 오류로 브레이크 캘리퍼가 기후적 요인으로 인해 내구성이 충분히 확보되지 않을 가능성이 있습니다.',
#        '차량 제작 과정에서 자동변속기 메카트로닉스의 상, 하부의 체결 나사의 조립 과정에서의 일부 나사의 체결이 누락되었을 가능성을 확인하였습니다.',
#        "휠을 생산하는 과정에서 휠의 규격을 타각하는 공정의 오류로 인해 직경을 의미하는 표기'J'가 누락되었을 가능성이 발견 되었습니다.",
#        '에어백 경고등 및 경고메시지를 작동시키는 컨트롤 유닛 소프트웨어 오류를 발견하였습니다. 소프트웨어의 오류로 인해 에어백 시스템, 액티브 보행자 보호장치, 고전압 시스템 충돌 차단장치 고장 발생 시, 에어백 경고등 또는 경고 메시지가 표시되지 않아 운전자가 해당 장치의 고장을 인지할 수 없습니다.',
#        '2019년 01월 30일부터 2019년 10월 21일까지 생산된 BMW M5, M8 Competition 모델 중 171대 차량의 변속기 배선 고정 공정 과정에서 배선을 고정하는 클립을 잘 못 장착하여 고정된 위치가 과도한 압착 및 변속기 등 주변에서 발생하는 열에 영향을 받아 배선이 단락 될 수 있습니다.',
#        'BMW 자체 품질 조사 결과 2019년 8월 2일 생산된 BMW X7 xDrive30d 차량에서 스티어링 스핀들* 관련한 제작결함이 발견 되었습니다. 생산과정에서의 조립공정 오류로 스티어링 스핀들 고정너트를 체결하지 않았을 가능성이 있습니다.',
#        '타이로드의 내구성 부족이 발견 되었습니다.',
#        'BMW 자체 품질 조사 결과 2019년 6월 26일 생산된 BMW Z4 sDrive20i 차량에서 연료탱크와 관련된 제작결함이 발견 되었습니다. 연료탱크를 생산하는 과정에서 상, 하부 플레이트*가 공정에 필요한 온도까지 가열되지 않은 것이 확인 되었습니다. 이로 인해 연료탱크의 상, 하단부의 접합이 정확하게 이루어지지 않을 수 있습니다. *상부, 하부 플레이트: 연료탱크 상, 하단부를 접합시키기 위한 프레스 장치',
#        'BMW 자체 품질 조사 결과 2021년 11월 22일부터 2021년 11월 30일까지 제작된 BMW i4 eDrive40, i4 M50 차량 72대의 차량 생산 과정에서 고전압 배터리 충격 완화 패드*가 장착되지 않았을 가능성을 확인하였습니다. *고전압 배터리 충격 완화 패드: 배터리와 차대 사이에 장착되어 측면 충돌 시 차대가 고전압 배터리에 손상을 입히는 것을 최소화하는 장치',
#        "주차거리 제어장치가 '자동차 및 자동차부품의 성능과 기준에 관한 규칙' 제53조의2(후방보행자 안전장치)의 제2항 접근 경보음 발생장치에서 정하는 감지영역 기준을 완전히 충족시키지 못하는 것으로 확인되었습니다.",
#        '대쉬보드를 생산하는 과정에서의 생산오류로 동반자석 에어백 고정 나사가 일부 체결되어있지 않았을 가능성이 있습니다.',
#        '스로틀 케이블의 장착 위치로 인해 집중적인 세척 또는 장시간의 우천 주행 시 스로틀 케이블 슬리브 내부에 물이 고이고 배수되지 않을 수 있는 가능성이 있습니다.',
#        '실 내외 조명 장치 등을 제어하는 Body Domain Controller(BDC)에 탑재된 소프트웨어에 오류가 있습니다.',
#        '2020년 11월 12일부터 2021년 1월19일까지 생산된 BMW 420i Convertible, 430i Convertible 차량에서 헤드에어백과 관련된 제작결함이 발견 되었습니다.',
#        '자체 품질 조사 결과 2021년 1월 28일 ~ 6월 29일 생산된 330e, 530e 모델 일부에서 제작 결함이 발견되었습니다. 배터리 셀 생산 공정 중 내부 전극이 정상적으로 재단되지 않아 와인딩 과정에서 분리막에 손상이 발생했을 가능성이 있습니다. *와인딩 : 고전압 배터리 셀 내부의 양극재, 분리막, 음극재 등 배터리 소재를 엮어서 돌돌 마는 고전압 배터리 제작 기법',
#        'BMW 자체 품질 조사 결과 2019년 02월 21일부터 2021년 06월 25일까지 제작된 BMW 540i xDrive, 540i xDrive Luxury, 630i xDrive, 630i xDrive Luxury, 640i xDrive, 640i xDrive Luxury, 745e iPerformance, 745Le iPerformance, M340i, M340I xDrive, M340i xDrive Touring, M440i xDrive, X3 M40i, X4 M40i, Z4 M40i 차량 총 5,656대에서 진공 펌프와 관련된 결함을 확인했습니다.',
#        'BMW 자체 품질 조사 결과 차량 생산 과정에서 앞 좌석 양측 시트에 안전벨트 버클이 제대로 고정되지 않은 것을 확인했습니다.',
#        '배터리 셀 생산 공정 중에 손상된 음극판 조각이 배터리 셀 내부에 유입되어 고전압 배터리에 단락이 발생할 수 있습니다.',
#        '실린더 헤드에 체결되어 있는 로커암 축 고정용 나사가 규정 토크로 조여지지 아니하였을 가능성이 있습니다.',
#        '배터리 관리 모듈(SME)*과 관련한 제작 결함이 발견되었습니다. *배터리 관리 모듈(SME): 고전압 배터리의 전력의 흐름을 조정 및 제어하며, 상태를 감시합니다. (충전 상태 및 배터리 상태)',
#        'BMW 자체 품질조사결과 2020년 2월 10일부터 2020년 11월 30일까지 생산된 BMW 840i xDrive Gran Coupe, M4 Competition, 740Li xDrive, 730d xDrive, 745e iPerformance, 740i, X5 xDrive30d, X6 xDrive30d, X7 M50d, X7 xDrive 30d, M8 Gran Coupe Competition, X6 M50d, X5 xDrive40i, M8 Coupe Competition, 730Ld xDrive, 745Le iPerformance, 840d xDrive Gran Coupe, 740d xDrive, X6 xDrive40i, X7 xDrive40i, X5 xDrive45e iPerformance, X5 M50i, X6 M Competition, X7 xDrive40d, 840i xDrive Coupe 차량의 일부에서 브레이크 하이드롤릭 유닛(유압제어장치)*과 관련한 제작결함이 발견 되었습니다. 하이드롤릭 유닛을 생산하는 과정에서 하이드롤릿 유닛 내 브레이크 신호를 감지하는 전자 모터의 로터**와 샤프트***간 용접불량으로 로터가 샤프트에 정확하게 고정되지 않았을 수 있습니다. *하이드롤릭 유닛(유압제어장치): 운전자의 브레이크 페달 신호를 감지하여 페달양에 따라 제동력을 발생시키는 장치 **로터: 전기 모터에서 전선이 감겨 회전하는 부품 ***샤프트: 로터와 고정된 축',
#        'BMW 자체품질조사결과 2020년 10월 03일부터 2021년 01월 11일까지 생산된 BMW X5 xDrive30d 등 3개 모델에서 발전기** +, - 배선의 고정과 관련한 제작결함이 발견되었습니다.',
#        'BMW 자체 품질조사결과 2020년 3월 13일부터 2020년 07월 06일까지 생산된 BMW 520i, 530i, 530i xDrive, 540i xDrive, 630i xDrive, 640i xDrive, 740Li xDrive 차량의 일부에서 뒤 드라이브샤프트*와 관련한 제작결함이 발견 되었습니다. 뒤 드라이브샤프트를 제조하는 공급업체에서 생산과정 중 담금질(Quenching)** 단계의 공정오류로 가열 후 냉각시간이 늦어 경도 및 강도가 저하되었을 수 있습니다. *드라이브샤프트: 엔진의 구동력을 구동바퀴로 전달하는 동력 전달 축 **담금질(Quenching): 금속의 강도를 높이기 위해 가열, 냉각을 반복하는 공정',
#        'BMW 자체 품질 조사 결과 2020년 9월 16일 생산된 BMW X6 xDrive40i 차량에서 스티어링 샤프트*의 유니버셜조인트**와 관련된 제작결함이 발견 되었습니다. 차량 생산과정에서 상, 하부의 스티어링 샤프트를 연결하는 유니버셜조인트의 고정볼트가 제대로 체결되지 않았을 가능성이 확인 되었습니다. *스티어링 샤프트: 스티어링 휠(핸들)과 연결되어 운전자의 회전 조작에 따라 함께 회전하는 축으로 차량의 선회 력을 전달 **유니버셜조인트: 두 개의 축을 연결하기 위하여 사용되는 연결장치로 각도와 길이 변화가 가능한 장치',
#        'BMW 자체 품질 조사 결과 2020년 11월 12일부터 2021년 1월19일까지 생산된 BMW 420i Convertible, 430i Convertible 차량에서 헤드에어백과 관련된 제작결함이 발견 되었습니다. 헤드에어백을 작동시키는 컨트롤유닛의 소프트웨어 오류가 확인 되었습니다.',
#        '당사의 문서번호『BGK-2020-A61-180』로 제출한 PHEV차량의 고전압 배터리 시정조치계획『2020RIV260』과 관련하여 고전압 배터리 품질에 관한 지속적인 분석 결과, BMW 독일본사로부터 문제가 발생할 가능성이 존재하는 차량이 발견되었습니다. 추가 된 대상 차량은 1)최초 고전압 배터리 성능 테스트를 통과하여 셀 모듈이 교체되지 않고 출고된 차량과 2)2020년 12월 실시된 『2020RIV260』 시정조치 당시 배터리가 이미 교체되었으나, 교체된 셀 모듈에서 추가 문제가 발생할 가능성이 있는 차량입니다',
#        '발전기 +, - 배선 설치 공정에서의 오류로 단자의 부 정확한 고정 가능성이 발견되었습니다',
#        'BMW 자체 품질 조사 결과 2021년 11월 12일부터 2021년 11월 23일까지 제작된 Rolls-Royce Ghost Black Badge, Phantom EWB, Cullinan 차량의 연료 탱크 조립 과정에서 연료 탱크와 연료 공급 파이프 연결 부품(커넥션)이 제대로 연결 되지 않았습니다.',
#        '당사의 문서번호 『BGK-2022-A61-073』로 2022년 07월 20일 제출한 에어백 컨트롤 유닛 시정조치계획보고와 관련하여 BMW 독일 본사로부터 에어백 컨트롤 유닛 내 액티브 보행자 보호장치 소프트웨어 오류가 있는 차량이 추가 발견되어 보고 드립니다. 에어백 컨트롤 유닛 내 액티브 보행자 보호장치 소프트웨어 오류로 차량 속도, 주행 방향, 외부 온도를 감지하는 센서 고장 시 경고등 또는 경고 메시지가 표시되지 않아 운전자가 해당 장치의 고장을 인지 및 수리를 제때 할 수 없을 수 있습니다',
#        '에어백 컨트롤 유닛 내 액티브 보행자 보호장치 소프트웨어 오류로 차량 속도, 주행 방향, 외부 온도를 감지하는 센서 고장 *액티브 보행자 보호장치 : 보행자와의 사고가 발생 할 경우, 차량 전면 후드를 들어올려 보행자가 받을 수 있는 충격을 감소시키는 장치',
#        '양측 앞좌석 시트, 뒷좌석 등받이 및 안전벨트의 나사가 제대로 조여지지 않았을 가능성이 확인되었습니다.이로 인해 양측 앞좌석 시트, 뒷좌석 등받이 및 안전벨트의 나사가 고정되지 않을 수 있습니다.',
#        '배터리 셀 생산 공정 중에 손상된 음극판 조각이 배터리 셀 내부에 유입되어 고전압 배터리에 단락이 발생할 수 있습니다',
#        'BMW 자체 품질 조사 결과 2019년 12월 4일부터 2020년 1월 23일까지 생산된 BMW X6 차량 일부에서 리어 스포일러(Rear Spoiler)*와 관련한 제작결함이 발견 되었습니다. 리어 스포일러를 생산하는 과정에서 접착제가 정상적으로 도포되지 않아 차체와의 접착력이 약할 수 있습니다. *리어 스포일러(Rear Spoiler): 차량 뒤 쪽에서 발생하는 공기의 와류현상을 없애며 차량 외관 장식을 위해 설치하는 장치',
#        '앞 좌석 A 필러 내부 금속판 고정 너트가 잘못 체결되거나, 부분적으로 체결되어있지 않을 수도 있습니다.',
#        'BMW 자체 품질 조사 결과 2020년 10월 19일부터 2021년 09월 22일까지 제작된 BMW iX xDrive40, iX xDrive50 차량 총 197대에서 테일게이트(트렁크) 컨트롤유닛 소프트웨어와 관련된 결함을 확인하였습니다. 테일게이트가 위로 열려있는 상황에서 겨울철 눈 쌓임 등, 테일게이트에 가해지는 외력이 특정값 이상으로 높아질 경우 자동으로 테일게이트가 닫 히도록 프로그래밍 되어있습니다. 이때 테일게이트(전동트렁크)가 닫히게 되는 외력의 설정값이 너무 낮게 설정되어 있습니다.',
#        '리어 스포일러(Rear Spoiler)*와 관련한 제작결함이 발견 되었습니다. 리어 스포일러를 생산하는 과정에서 접착제가 정상적으로 도포되지 않아 차체와의 접착력이 약할 수 있습니다. *리어 스포일러(Rear Spoiler): 차량 뒤 쪽에서 발생하는 공기의 와류현상을 없애며 차량 외관 장식을 위해 설치하는 장치',
#        '2020년 7월 10일 생산된 BMW X7 xDrive30d, X5 M50d 차량에서 스타트 모터 고정볼트와 관련한 제작결함이 발견 되었습니다. 스타트 모터를 엔진에 장착시키는 생산공정에서 조립 오류로 스타트 모터* 고정볼트를 부 정확하게 체결하여 플라이 휠**과 간섭이 발생할 수 있습니다. *스타트 모터: 엔진의 시동을 위해 플라이 휠을 돌려주는 전기 모터 **플라이 휠: 엔진의 시동을 위해 크랭크축과 연결된 장치로, 스타트 모터가 작동 시 플라이 휠의 기어와 맞물려 회전',
#        '당사의 문서번호『BGK-2020-A61-138』로 제출한 PHEV차량의 고전압 배터리 시정조치계획사전보고와 관련하여 BMW 독일본사로부터 추가적인 점검 방법과 점검 결과에 따른 기술적 조치 사항에 대한 내용을 전달 받아 정식 보고 드립니다. 점검 방법의 경우 고객에게 기 판매된 차량에 대해서는 고전압 배터리의 충전이력을 점검하여 80%이상 충전 이력이 확인된 차량은 고객에게 인도하여 차량 운행이 가능하도록 인도하는 방식에서 80%이상의 충전이력을 확인하고 확인된 차량에 한 하여 완전충전(100%) 기록이 차량에 수록되어 있는 경우에만 고객에게 인도하며 정상판정 기준의 충전이력이 확인되지 않은 차량의 경우 고전압 배터리 셀 모듈을 교체합니다. 또한 고객에게 판매되지 않은 차량에 대해서는 고전압 배터리를 완전 충전시킨 뒤 2시간동안 그대로 두고 35% 수준까지 방전시킨 뒤 전용 진단기를 통해 고장메모리의 수록 여부를 판독하여 고장메모리가 확인되면 고전압 배터리 셀 모듈을 교체 합니다. 판매 전 차량을 점검하는 과정에서 화재발생 시 해당 차량은 폐기 될 예정입니다. 금번 시정조치 사유는 기 사전보고 드렸던 내용과 동일하게, 고전압 배터리 팩 용접 시 발생하는 이물질을 제거하기 위한 세척 공정이 불 충분하여 고전압 배터리 팩 내에 이물질이 남아있을 수 있습니다. 이물질의 크기, 위치 등에 따라 충전 시 고전압 배터리의 팽창에 따른 배터리 팩과 이물질간 눌림이 발생하여 첫 번째 충전에서 80%이상 충전 시 고전압 배터리가 단락 되며 드문 경우 화재발생 가능성이 확인 되어 해당 시정조치를 실시합니다.',
#        'BMW 자체 품질 조사 결과 2020년 6월 1일부터 2020년 6월 28일까지 생산된 BMW X5 M, X5 M50i, X5 xDrive30d, X5 xDrive40i, X5 xDrive45e iPerformance, X6 M, X6 xDrive30d, X6 xDrive40i, X7 M50i, X7 xDrive30d, X7 xDrive40i 차량에서 앞 차축(서브프레임)*과 관련된 제작결함이 발견 되었습니다. 앞 차축(서브 프레임)*을 생산하는 설비 중 용접장비가 유지보수 작업 후 정확한 용접위치로 조정되지 않은 것이 확인 되었습니다.',
#        '발전기 +, - 배선 설치 공정에서의 오류로 단자의 부 정확한 고정 가능성으로 단자와 배선의 접촉이 완결하지 않을 수 있습니다.',
#        '배터리 셀의 제조공정 과정에서 배터리 셀 내에 이물질(용접비산물질)이 완벽하게 제거되지 않았을 가능성이 있습니다.',
#        '고전압 배터리 팩 용접 시 발생하는 이물질을 제거하기 위한 세척 공정이 불 충분하여 고전압 배터리 팩 내에 이물질이 남아있을 수 있습니다.',
#        'BMW 자체 품질 조사 결과 2020년 3월 18일부터 2020년 10월 2일까지 생산된 BMW M2, M4 Coupe차량에서 인젝터 와셔(디 커플링)*와 관련된 제작결함이 발견 되었습니다. 엔진 생산 과정에서 인젝터 와셔의 미 장착 가능성이 있습니다. *인젝터 와셔(디 커플링): 기밀유지 등의 목적으로 인젝터와 실린더헤드 사이에 위치하는 부품',
#        '‘자동차 및 자동차부품의 성능과 기준에 관한 규칙’ 제40조의3(주차등) 조항에 따르면, 길이가 600센티미터 이하, 너비가 200센티미터 이하인 자동차에 주차등 설치를 허용하고 있으며, 설치 하려는 때에는 별표6의32 기준을 충족할 것을 요구하고 있습니다. 그리고 동 규칙 제47조 제3항에 따르면, 제40조의3에 규정되지 아니한 등화나 반사기 등을 설치하는 것은 금지되고 있습니다. *주차등: 이면도로 등에 주차된 차량의 추돌사고 등을 방지하기 위한 목적으로 차량의 위치를 알리고자 주차 후 좌측 또는 우측의 후미등을 켤 수 있도록 하는 기능',
#        '해당 차량에 다른 사양의 휠 볼트가 장착되었을 가능성을 발견했습니다.',
#        '배터리 셀 생산 공정 중에 손상된 음극판 조각이 배터리 셀 내부에 유입되어 고전압 배터리에 단락이 발생 할 수 있습니다',
#        'BMW 자체 품질조사결과 2021년 02월 23일부터 2021년 02월 26일까지 생산 된 BMW i3 120Ah 차량의 뒷좌석 양쪽 백레스트 프레임(Backrest frame)*의 제작결함이 발견 되었습니다.',
#        '에어백 컨트롤 유닛 내 액티브 보행자 보호장치 소프트웨어 오류를 발견하였습니다. 에어백 컨트롤 유닛 내 액티브 보행자 보호장치 소프트웨어 오류로 차량 속도, 주행 방향, 외부 온도를 감지하는 센서 고장 시, 경고등 또는 경고 메시지가 표시되지 않아 운전자가 해당 장치의 고장을 인지 및 수리를 제때 할 수 없을 수 있습니다.',
#        "BMW 자체 품질 조사 결과 2022년 6월 20일부터 2022년 08월 04일까지 제작된 BMW 740i, i7 xdrive60 차량의 주차등에서 제작 결함이 발견되었습니다. 외부 조명등(헤드라이트/방향지시등/주간주행등/차폭등)을 제어하는 소프트웨어 오류로 인해 주차등을 작동시킬 경우 차량 전면부 그릴 등화가 소등되지 않고 점등되어, '자동차 및 자동차 부품의 성능과 기준에 관한 규칙' 제 40조의 3(주차등)의 별표 6의 32 작동기준을 충족하지 못하는 것으로 확인되었습니다.",
#        '에어백 컨트롤 유닛 내 액티브 보행자 보호장치 소프트웨어 오류가 발견되었습니다.',
#        '경음기 체결 볼트의 설계상 오류로 경음기가 차체에 제대로 고정되지 아니하여 경음기가 차체에서 이탈될 수 있는 가능성이 있습니다.',
#        '2020년 01월 27일부터 2020년 03월 11일까지 생산된 BMW 118d, 220d 차량에서 운전석 에어백과 관련한 제작결함이 발견 되었습니다. 에어백하우징과 에어백 사이 마찰되는 영역의 내구성이 낮아 에어백 전개 시 에어백하우징에 의해 손상될 수 있습니다.',
#        'BMW 자체 품질조사결과 2021년 1월 27일부터 2021년 2월 5일까지 생산된 BMW 520i, 523d, 523d xDrive, 530e iPerformance, 530i, 530i xDrive, 620d, 620d xDrive, 630i xDrive, 730d xDrive, 730Ld xDrive, 740i, 740Li xDrive, 745e iPerformance, M340i, M340i xDrive Touring, M440i xDrive, Z4 M40i, Z4 sDrive20i 차량의 일부에서 브레이크 디스크*와 관련한 제작결함이 발견 되었습니다. 브레이크 디스크를 생산하는 과정에서 챔버**와 조립 시 지정된 리벳***보다 짧은 길이의 리벳을 사용한 것이 확인 되었습니다.',
#        '자동변속기 내부 주차 기어를 고정하는 이탈 방지 링의 제작 과정 상 오류로 주차 기어가 이탈될 수 있습니다.',
#        '안전벨트 버클을 생산하는 과정에서의 생산오류(센서의 배선이 설계된 것 보다 짧게 연결되어 부 정확하게 조립)',
#        '클러치 커버 고정 볼트가 제조 공정상의 불균일한 부식 방지제 코딩으로 인해 볼트가 제대로 조여지지 아니하여 풀릴 수 있는 가능성이 있습니다.',
#        '운전석 차문 내부에서 차문 외부 손잡이와 차문 잠금 장치 사이에 장착되어야 하는 어댑터 브라켓이 장착되지 않았을 가능성이 있습니다 *어댑터 브라켓: 차문 외부 손잡이의 열쇠 실린더와 도어 잠금 장치 사이에 연결되어 차량의 잠금을 조작할 수 있는 연결봉(커넥팅 로드)의 덮개로서, 외부로부터의 차문 잠금 상태의 수동 조작을 방지합니다. 또한 측면 충격 등에 의해 장치들의 위치 변경이 발생 경우, 차문 외부 손잡이와 도어 잠금 장치 사이를 고정하여 구조적 위치를 유지시켜 주는 구성품',
#        'BMW 자체 품질조사결과 2021년 02월 09일에 생산 된 BMW X5 xDrive 45e 차량에서 뒷좌석 창가 쪽 양쪽 머리받침대의 제작결함이 발견 되었습니다.'],
#       dtype=object)

# %%
df_bmw[df_bmw['리콜사유'].str.contains('EGR 쿨러의')].head()
# Out:
#              제작자                    차명    생산기간(부터)  \
# 668  비엠더블유코리아(주)  MINI Cooper SD Coupe  2012-06-19
# 512  비엠더블유코리아(주)      BMW 520d Touring  2012-03-29
# 522  비엠더블유코리아(주)              BMW 525d  2012-07-04
# 536  비엠더블유코리아(주)              BMW 535d  2011-09-05
# 667  비엠더블유코리아(주)  MINI Cooper SD Coupe  2012-07-06
#
#                                                   리콜사유  리콜_년  리콜_월  리콜_일  \
# 668  당사는 당사의 EGR 쿨러가 이전 리콜 대상 EGR 쿨러에 비하여 개선되고 최적화 ...  2020    10     1
# 512  당사는 당사의 EGR 쿨러가 이전 리콜 대상 EGR 쿨러에 비하여 개선되고 최적화 ...  2020     6     1
# 522  당사는 당사의 EGR 쿨러가 이전 리콜 대상 EGR 쿨러에 비하여 개선되고 최적화 ...  2020     6     1
# 536  당사는 당사의 EGR 쿨러가 이전 리콜 대상 EGR 쿨러에 비하여 개선되고 최적화 ...  2020     6     1
# 667  당사는 당사의 EGR 쿨러가 이전 리콜 대상 EGR 쿨러에 비하여 개선되고 최적화 ...  2020     6     1
#
#      출고_년  출고_월  출고_일  사용기간
# 668  2012    11    29     8
# 512  2012    10     2     8
# 522  2012    10    17     8
# 536  2012     8    27     8
# 667  2012     9     4     8

# %%
# 주요 원인이 포함된 이유 상세 보기
df_bmw_recall = df_bmw[df_bmw['리콜사유'].str.contains('EGR 쿨러의')]
df_bmw_recall['리콜사유'].drop_duplicates().values
# Out:
# array(['당사는 당사의 EGR 쿨러가 이전 리콜 대상 EGR 쿨러에 비하여 개선되고 최적화 되었음을 입증하였습니다. 당사의 철학과 경영 정책에 따라, 개별 현장 사례의 분석을 계속하였습니다. 그 결과, 지속적인 노력을 통해 상황이 개선되었음에도, 현장에서 적은 수이기는 하나 EGR 쿨러의 누수가 의심되는 사례를 관찰하게 되었습니다. 이에 고객의 이익과 편의를 충실히 보호하고, 동시에 당사에 매우 중요한 한국 시장을 보호하기 위하여, 현장의 적은 수이기는 하나 이러한 의심 사례를 대처하고 해소하기 위한 예방적인 조치를 취하기로 결정하였습니다. 중요한 점으로서, 당사는 귀 기관과 자동차안전연구원에 모든 것을 투명하게 공개하며, 위와 같은 상황을 명확히 전달 드려왔고, 귀 기관 및 자동차안전연구원과의 충분한 논의를 거친 후, 이번 리콜을 시행하기로 결정하였다는 점을 말씀드립니다.'],
#       dtype=object)

# %%
df_bmw_recall['차명'].drop_duplicates().values
# Out:
# array(['MINI Cooper SD Coupe', 'BMW 520d Touring', 'BMW 525d', 'BMW 535d',
#        'BMW X1 xDrive25d', 'MINI Cooper SD Paceman ALL4',
#        'MINI Cooper SD Paceman', 'BMW 328d', 'MINI Cooper D',
#        'BMW Gran Turismo 20d', 'MINI Cooper D Paceman',
#        'MINI Cooper D Paceman ALL4', 'BMW X3 xDrive35d',
#        'BMW Gran Turismo 30d', 'BMW Gran Turismo 30d xDrive',
#        'MINI Cooper SD', 'MINI Cooper SD Clubman', 'BMW 740d',
#        'BMW 525d xDrive', 'BMW 520d', 'BMW 730d',
#        'BMW 525d xDrive Touring', 'BMW 420d xDrive Coupe',
#        'BMW 420d xDrive Gran Coupe', 'BMW 520d xDrive', 'BMW 730Ld',
#        'BMW 535d xDrive', 'MINI Cooper SD Countryman',
#        'MINI Cooper D Clubman', 'BMW X6 M50d', 'BMW X5 xDrive35d',
#        'BMW X3 xDrive30d', 'BMW X3 xDrive20d', 'BMW 328d xDrive',
#        'BMW 325d', 'BMW 120d', 'BMW 220d Coupe', 'BMW 420d Coupe',
#        'BMW 750Ld xDrive', 'BMW 740d xDrive', 'BMW 730d xDrive',
#        'BMW X4 xDrive30d', 'BMW M550d xDrive', 'BMW 320d Touring',
#        'BMW 320d', 'BMW 320d EfficientDynamics Edition',
#        'BMW 520d xDrive Touring', 'BMW 320d Gran Turismo',
#        'BMW 320d xDrive Gran Turismo', 'BMW 518d', 'BMW 420d Gran Coupe',
#        'BMW 640d xDrive Gran Coupe', 'MINI Cooper D Countryman',
#        'MINI Cooper SD five-door', 'MINI Cooper D Countryman ALL4',
#        'MINI Cooper SD Countryman ALL4', 'BMW 530d xDrive',
#        'BMW 435d xDrive Gran Coupe',
#        'BMW Gran Turismo EfficientDynamics Edition', 'BMW X1 xDrive18d',
#        'BMW X1 xDrive20d', 'BMW 320d xDrive', 'BMW Active Tourer',
#        'BMW 420d', 'MINI Cooper D five-door', 'BMW X4 xDrive20d',
#        'BMW X5 M50d', 'BMW X5 xDrive40d', 'BMW X5 xDrive25d',
#        'BMW X5 xDrive30d', 'BMW 740Ld xDrive', 'BMW 730Ld xDrive',
#        'BMW 630d xDrive', 'BMW X4 M40d', 'BMW 530d', 'BMW X7 xDrive30d',
#        'BMW 118d', 'BMW X6 xDrive40d', 'BMW X6 xDrive30d'], dtype=object)

# %%
# 주요 원인으로 리콜된 가장 나쁜 모델3개는?

tmp = df_bmw_recall.groupby('차명').size().sort_values(ascending=False).to_frame('count').head(10)
print(tmp)
# Out:
#                               count
# 차명
# BMW 520d                          8
# BMW 320d Gran Turismo             6
# BMW 420d Gran Coupe               6
# BMW 320d xDrive Gran Turismo      6
# BMW 520d xDrive                   6
# BMW X3 xDrive20d                  6
# BMW 420d xDrive Gran Coupe        5
# BMW X6 M50d                       4
# MINI Cooper D                     4
# BMW 730d xDrive                   4

# %%
tmp = df_bmw_recall.groupby('차명').size().sort_values(ascending=False).to_frame('count')
print(f'주요 원인으로 리콜된 가장 나쁜 모델3개는? {tmp.index[0], tmp.index[1], tmp.index[2]}')
# Out:
# 주요 원인으로 리콜된 가장 나쁜 모델3개는? ('BMW 520d', 'BMW 320d Gran Turismo', 'BMW 420d Gran Coupe')

# %% [markdown]
# ```
# 리콜 주요 원인은? EGR 쿨러의 누수가 의심
#
# 그래서, 가장 나쁜 모델은?  'BMW 520d'
# ```
#
# 당사는 당사의 EGR 쿨러가 이전 리콜 대상 EGR 쿨러에 비하여 개선되고 최적화 되었음을 입증하였습니다. 당사의 철학과 경영 정책에 따라, 개별 현장 사례의 분석을 계속하였습니다. 그 결과, 지속적인 노력을 통해 상황이 개선되었음에도, 현장에서 적은 수이기는 하나 'EGR 쿨러의 누수가 의심'되는 사례를 관찰하게 되었습니다. 이에 고객의 이익과 편의를 충실히 보호하고, 동시에 당사에 매우 중요한 한국 시장을 보호하기 위하여, 현장의 적은 수이기는 하나 이러한 의심 사례를 대처하고 해소하기 위한 예방적인 조치를 취하기로 결정하였습니다. 중요한 점으로서, 당사는 귀 기관과 자동차안전연구원에 모든 것을 투명하게 공개하며, 위와 같은 상황을 명확히 전달 드려왔고, 귀 기관 및 자동차안전연구원과의 충분한 논의를 거친 후, 이번 리콜을 시행하기로 결정하였다는 점을 말씀드립니다.
